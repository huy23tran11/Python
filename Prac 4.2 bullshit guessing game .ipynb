# %%
from random import randint
result = randint(0,101)
print(' choi game di thang ngu \n')
guessing=101
index =0
while(1):
    #guessing = input ('{} nhap 1 so di thang ngu\n'.format(result))
    guessing = input (' nhap 1 so di thang ngu\n')
    guessing=int(guessing)
    index +=1
    
    if (index ==1 ):
        if (guessing < 0 or guessing > 100):
            print('out of bond !')
        elif ((guessing == result)):
            print('vai lozzzzzzz')
            break
        elif (abs(guessing-result)<=10):
            print("WARM!")
        else :
            print("COLD!")
        guessing_old = guessing
        #print(guessing_old)
        
        
    else:
        if (guessing < 0 or guessing > 100):
            print('out of bond !')
        elif ((guessing == result)):
            print('hen vl')
            break
        elif (abs(guessing-result)<abs(guessing_old-result)):
            print('WARMER')
        elif (abs(guessing-result)>abs(guessing_old-result)):
            print('COLDER')            
        guessing_old = guessing 
print('so lan dem {}'.format (index))
# Out:
#  choi game di thang ngu
#
#  nhap 1 so di thang ngu
# 1
# COLD!
#  nhap 1 so di thang ngu
# 2
# WARMER
#  nhap 1 so di thang ngu
# 6
# WARMER
#  nhap 1 so di thang ngu
# 6
#  nhap 1 so di thang ngu
# 85
# COLDER
#  nhap 1 so di thang ngu
# 20
# WARMER
#  nhap 1 so di thang ngu
# 50
# COLDER
#  nhap 1 so di thang ngu
# 30
# WARMER
#  nhap 1 so di thang ngu
# 40
# COLDER
#  nhap 1 so di thang ngu
# 35
# WARMER
#  nhap 1 so di thang ngu
# 32
# WARMER
#  nhap 1 so di thang ngu
# 31
# WARMER
#  nhap 1 so di thang ngu
# 30
# WARMER
#  nhap 1 so di thang ngu
# 29
# WARMER
#  nhap 1 so di thang ngu
# 25
# WARMER
#  nhap 1 so di thang ngu
# 22
# COLDER
#  nhap 1 so di thang ngu
# 26
# hen vl
# so lan dem 17

# %%
from random import randint
result = randint(0,101)
print(' choi game di thang ngu \n')
guess=[]
while (1):
    guess_var=int(input('nhap 1 so dee '))
    
    if (guess_var<0) or (guess_var >100) :
        print(' out of bond ')
        continue
    guess.append(guess_var)
    if guess_var==result:
        print('hay z may dem dc trong {} buoc luon !!!!!'.format(len(guess)))
        break
    elif len(guess) ==1:
        if abs(guess[0]-result) <=10:
            print('WARM!')
        else :
            print('COLD!')
    elif len(guess) >1:
        if abs(guess[-1]- result) <=  abs(guess[-2]- result) :
            print('WARMER!')
        elif abs(guess[-1]- result) >  abs(guess[-2]- result) :
            print('COLDER!')
